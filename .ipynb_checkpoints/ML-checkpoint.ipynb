# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

np.random.seed(0)
n_samples = 100

# Features
math_score = np.random.randint(50, 100, n_samples)
english_score = np.random.randint(50, 100, n_samples)
extracurricular = np.random.randint(0, 2, n_samples)  # 0: No, 1: Yes

# Rule: đậu nếu tổng > 160 hoặc có hoạt động ngoại khoá tốt
passed = ((math_score + english_score) > 160) | ((extracurricular == 1) & ((math_score + english_score) > 140))
passed = passed.astype(int)

df = pd.DataFrame({
    'math_score': math_score,
    'english_score': english_score,
    'extracurricular': extracurricular,
    'passed': passed
})

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 4
#       2 import numpy as np
#       3 from sklearn.preprocessing import StandardScaler
# ----> 4 from imblearn.over_sampling import RandomOverSampler
#       6 np.random.seed(0)
#       7 n_samples = 100
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
cols = ['math_score', 'english_score', 'extracurricular','passed']

for label in cols[:-1]:
    plt.hist(df[df["passed"] == 1][label], color='blue', label='pass', alpha=0.7, density=True)
    plt.hist(df[df["passed"] == 0][label], color='red', label='failed', alpha=0.7, density=True)
    plt.title(label)
    plt.ylabel("Probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()

# %% [markdown]
# # Train validatio, and test datasets

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])

# %%
from imblearn.over_sampling import RandomOverSampler

def scale_dataset(dataframe):
    x = dataframe[dataframe.cols[:-1]].values
    y = dataframe[dataframe.cols[-1]].values

    scaler = StandardScaler()
    x = scaler.fit_transform(x)

    data = np.hstack((X, np.reshape(y, (-1,1))))

    return data, x , y
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from imblearn.over_sampling import RandomOverSampler
#       3 def scale_dataset(dataframe):
#       4     x = dataframe[dataframe.cols[:-1]].values
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
print(len(train[train["passed"]==1]))
print(len(train[train["passed"]==0]))
# Out:
# 33
# 27

# %% [raw]
# pip install imbalanced-learn

# %%
pip show imbalanced-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: imbalanced-learn
